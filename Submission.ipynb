# %% [markdown]
# ## Setup

# %%
import pandas as pd
import logging 
import sys
import os
sys.path.insert(0,'./src')


from src.utils.logger import sys_logger

os.makedirs("./final_data", exist_ok=True)

# %% [markdown]
# ## Landing Zone to Staging

# %%
from src.utils.splitter import split_files

split_files()
# Out:
# [splitter.py:9]                 Files in landing zone: ['customer_20241009.csv', 'customer_20241010.csv', 'customer_20241011.csv', 'customer_20241012.csv', 'customer_20241013.csv', 'customer_20241014.csv', 'customer_20241015.csv', 'products_20241009.json', 'products_20241010.json', 'products_20241011.json', 'products_20241012.json', 'products_20241013.json', 'products_20241014.json', 'products_20241015.json', 'sales_20241009.txt', 'sales_20241010.txt', 'sales_20241011.txt', 'sales_20241012.txt', 'sales_20241013.txt', 'sales_20241014.txt', 'sales_20241015.txt']
# [splitter.py:14]                customer_20241009.csv matched with customer
# [splitter.py:17]                customer_20241009.csv moved to ./data/customer/
# [splitter.py:14]                customer_20241010.csv matched with customer
# [splitter.py:17]                customer_20241010.csv moved to ./data/customer/
# [splitter.py:14]                customer_20241011.csv matched with customer
# [splitter.py:17]                customer_20241011.csv moved to ./data/customer/
# [splitter.py:14]                customer_20241012.csv matched with customer
# [splitter.py:17]                customer_20241012.csv moved to ./data/customer/
# [splitter.py:14]                customer_20241013.csv matched with customer
# [splitter.py:17]                customer_20241013.csv moved to ./data/customer/
# [splitter.py:14]                customer_20241014.csv matched with customer
# [splitter.py:17]                customer_20241014.csv moved to ./data/customer/
# [splitter.py:14]                customer_20241015.csv matched with customer
# [splitter.py:17]                customer_20241015.csv moved to ./data/customer/
# [splitter.py:14]                products_20241009.json matched with product
# [splitter.py:17]                products_20241009.json moved to ./data/products/
# [splitter.py:14]                products_20241010.json matched with product
# [splitter.py:17]                products_20241010.json moved to ./data/products/
# [splitter.py:14]                products_20241011.json matched with product
# [splitter.py:17]                products_20241011.json moved to ./data/products/
# [splitter.py:14]                products_20241012.json matched with product
# [splitter.py:17]                products_20241012.json moved to ./data/products/
# [splitter.py:14]                products_20241013.json matched with product
# [splitter.py:17]                products_20241013.json moved to ./data/products/
# [splitter.py:14]                products_20241014.json matched with product
# [splitter.py:17]                products_20241014.json moved to ./data/products/
# [splitter.py:14]                products_20241015.json matched with product
# [splitter.py:17]                products_20241015.json moved to ./data/products/
# [splitter.py:14]                sales_20241009.txt matched with sales
# [splitter.py:17]                sales_20241009.txt moved to ./data/sales/
# [splitter.py:14]                sales_20241010.txt matched with sales
# [splitter.py:17]                sales_20241010.txt moved to ./data/sales/
# [splitter.py:14]                sales_20241011.txt matched with sales
# [splitter.py:17]                sales_20241011.txt moved to ./data/sales/
# [splitter.py:14]                sales_20241012.txt matched with sales
# [splitter.py:17]                sales_20241012.txt moved to ./data/sales/
# [splitter.py:14]                sales_20241013.txt matched with sales
# [splitter.py:17]                sales_20241013.txt moved to ./data/sales/
# [splitter.py:14]                sales_20241014.txt matched with sales
# [splitter.py:17]                sales_20241014.txt moved to ./data/sales/
# [splitter.py:14]                sales_20241015.txt matched with sales
# [splitter.py:17]                sales_20241015.txt moved to ./data/sales/

# %% [markdown]
# ## Staging to Tables

# %%
from src.utils.ingestion import run_ingestion

run_ingestion()
# Out:
# [watermark.py:8]                Reading watermark table from ./watermark.parquet
# [watermark.py:12]               Watermark table not found at ./watermark.parquet. Creating new table
# [watermark.py:14]               Watermark table has 0 rows
# [ingestion.py:12]               Loading customer data
# [watermark.py:18]               Getting last run date for customer
# [watermark.py:21]               No previous runs found for customer
# [files.py:10]                   Getting files to process from ./data/customer/
# [files.py:14]                   Found 7 files to process
# [ingestion.py:19]               Processing customer_20241009.csv
# [files.py:26]                   Reading csv file from ./data/customer/customer_20241009.csv with kwargs {'sep': ','}
# [dataframes.py:134]             Processing data for customer
# [files.py:55]                   Getting saved file for customer
# [files.py:18]                   Getting save filename for customer
# [files.py:34]                   Reading parquet file from ./final_data/customer.parquet
# [files.py:60]                   File not found at ./final_data/customer.parquet. Creating new file
# [files.py:62]                   customer file has 0 rows
# [dataframes.py:49]              Processing file with 5000 records.
# [dataframes.py:82]              Detected 0 old records and 5000 new records.
# [files.py:18]                   Getting save filename for customer
# [files.py:22]                   Saving file with 5000 rows to ./final_data/customer.parquet
# [dataframes.py:165]             Processed 5000 records for customer
# [watermark.py:38]               Updating watermark table with {'source': 'customer', 'processed_rows': 5000, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:00.868892'), 'file_date': Timestamp('2024-10-09 00:00:00'), 'file_id': 'f8ed182d-f7bb-45be-8567-0eed50f691fb', 'file_name': 'customer_20241009.csv'}
# [watermark.py:40]               Watermark table now has 1 rows
# [files.py:22]                   Saving file with 1 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed customer_20241009.csv
# [ingestion.py:19]               Processing customer_20241010.csv
# [files.py:26]                   Reading csv file from ./data/customer/customer_20241010.csv with kwargs {'sep': ','}
# [dataframes.py:134]             Processing data for customer
# [files.py:55]                   Getting saved file for customer
# [files.py:18]                   Getting save filename for customer
# [files.py:34]                   Reading parquet file from ./final_data/customer.parquet
# [files.py:62]                   customer file has 5000 rows
# [dataframes.py:49]              Processing file with 5280 records.
# [dataframes.py:82]              Detected 802 old records and 1082 new records.
# [files.py:18]                   Getting save filename for customer
# [files.py:22]                   Saving file with 6082 rows to ./final_data/customer.parquet
# [dataframes.py:165]             Processed 5280 records for customer
# [watermark.py:38]               Updating watermark table with {'source': 'customer', 'processed_rows': 5280, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:01.199918'), 'file_date': Timestamp('2024-10-10 00:00:00'), 'file_id': 'fbc190ba-3ecb-4fee-b706-2ab645471718', 'file_name': 'customer_20241010.csv'}
# [watermark.py:40]               Watermark table now has 2 rows
# [files.py:22]                   Saving file with 2 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed customer_20241010.csv
# [ingestion.py:19]               Processing customer_20241011.csv
# [files.py:26]                   Reading csv file from ./data/customer/customer_20241011.csv with kwargs {'sep': ','}
# [dataframes.py:134]             Processing data for customer
# [files.py:55]                   Getting saved file for customer
# [files.py:18]                   Getting save filename for customer
# [files.py:34]                   Reading parquet file from ./final_data/customer.parquet
# [files.py:62]                   customer file has 6082 rows
# [dataframes.py:49]              Processing file with 5576 records.
# [dataframes.py:82]              Detected 819 old records and 1115 new records.
# [files.py:18]                   Getting save filename for customer
# [files.py:22]                   Saving file with 7197 rows to ./final_data/customer.parquet
# [dataframes.py:165]             Processed 5576 records for customer
# [watermark.py:38]               Updating watermark table with {'source': 'customer', 'processed_rows': 5576, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:01.455940'), 'file_date': Timestamp('2024-10-11 00:00:00'), 'file_id': '98890008-1f13-4e3d-9363-a1b5e5dd6796', 'file_name': 'customer_20241011.csv'}
# [watermark.py:40]               Watermark table now has 3 rows
# [files.py:22]                   Saving file with 3 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed customer_20241011.csv
# [ingestion.py:19]               Processing customer_20241012.csv
# [files.py:26]                   Reading csv file from ./data/customer/customer_20241012.csv with kwargs {'sep': ','}
# [dataframes.py:134]             Processing data for customer
# [files.py:55]                   Getting saved file for customer
# [files.py:18]                   Getting save filename for customer
# [files.py:34]                   Reading parquet file from ./final_data/customer.parquet
# [files.py:62]                   customer file has 7197 rows
# [dataframes.py:49]              Processing file with 5888 records.
# [dataframes.py:82]              Detected 884 old records and 1196 new records.
# [files.py:18]                   Getting save filename for customer
# [files.py:22]                   Saving file with 8393 rows to ./final_data/customer.parquet
# [dataframes.py:165]             Processed 5888 records for customer
# [watermark.py:38]               Updating watermark table with {'source': 'customer', 'processed_rows': 5888, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:01.729450'), 'file_date': Timestamp('2024-10-12 00:00:00'), 'file_id': '22558ba5-8d61-4e5f-92a0-96a21f610131', 'file_name': 'customer_20241012.csv'}
# [watermark.py:40]               Watermark table now has 4 rows
# [files.py:22]                   Saving file with 4 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed customer_20241012.csv
# [ingestion.py:19]               Processing customer_20241013.csv
# [files.py:26]                   Reading csv file from ./data/customer/customer_20241013.csv with kwargs {'sep': ','}
# [dataframes.py:134]             Processing data for customer
# [files.py:55]                   Getting saved file for customer
# [files.py:18]                   Getting save filename for customer
# [files.py:34]                   Reading parquet file from ./final_data/customer.parquet
# [files.py:62]                   customer file has 8393 rows
# [dataframes.py:49]              Processing file with 6217 records.
# [dataframes.py:82]              Detected 917 old records and 1246 new records.
# [files.py:18]                   Getting save filename for customer
# [files.py:22]                   Saving file with 9639 rows to ./final_data/customer.parquet
# [dataframes.py:165]             Processed 6217 records for customer
# [watermark.py:38]               Updating watermark table with {'source': 'customer', 'processed_rows': 6217, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:02.022473'), 'file_date': Timestamp('2024-10-13 00:00:00'), 'file_id': 'd246e24b-a548-4853-8b19-8e36a072f5aa', 'file_name': 'customer_20241013.csv'}
# [watermark.py:40]               Watermark table now has 5 rows
# [files.py:22]                   Saving file with 5 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed customer_20241013.csv
# [ingestion.py:19]               Processing customer_20241014.csv
# [files.py:26]                   Reading csv file from ./data/customer/customer_20241014.csv with kwargs {'sep': ','}
# [dataframes.py:134]             Processing data for customer
# [files.py:55]                   Getting saved file for customer
# [files.py:18]                   Getting save filename for customer
# [files.py:34]                   Reading parquet file from ./final_data/customer.parquet
# [files.py:62]                   customer file has 9639 rows
# [dataframes.py:49]              Processing file with 6565 records.
# [dataframes.py:82]              Detected 974 old records and 1322 new records.
# [files.py:18]                   Getting save filename for customer
# [files.py:22]                   Saving file with 10961 rows to ./final_data/customer.parquet
# [dataframes.py:165]             Processed 6565 records for customer
# [watermark.py:38]               Updating watermark table with {'source': 'customer', 'processed_rows': 6565, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:02.354500'), 'file_date': Timestamp('2024-10-14 00:00:00'), 'file_id': 'b4e0f954-c7ff-413c-a70b-93fae2dbb8c5', 'file_name': 'customer_20241014.csv'}
# [watermark.py:40]               Watermark table now has 6 rows
# [files.py:22]                   Saving file with 6 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed customer_20241014.csv
# [ingestion.py:19]               Processing customer_20241015.csv
# [files.py:26]                   Reading csv file from ./data/customer/customer_20241015.csv with kwargs {'sep': ','}
# [dataframes.py:134]             Processing data for customer
# [files.py:55]                   Getting saved file for customer
# [files.py:18]                   Getting save filename for customer
# [files.py:34]                   Reading parquet file from ./final_data/customer.parquet
# [files.py:62]                   customer file has 10961 rows
# [dataframes.py:49]              Processing file with 6933 records.
# [dataframes.py:82]              Detected 1041 old records and 1409 new records.
# [files.py:18]                   Getting save filename for customer
# [files.py:22]                   Saving file with 12370 rows to ./final_data/customer.parquet
# [dataframes.py:165]             Processed 6933 records for customer
# [watermark.py:38]               Updating watermark table with {'source': 'customer', 'processed_rows': 6933, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:02.655521'), 'file_date': Timestamp('2024-10-15 00:00:00'), 'file_id': 'e28bd1e0-b9b4-4d8f-9a54-639d87ea2854', 'file_name': 'customer_20241015.csv'}
# [watermark.py:40]               Watermark table now has 7 rows
# [files.py:22]                   Saving file with 7 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed customer_20241015.csv
# [ingestion.py:12]               Loading sales data
# [watermark.py:18]               Getting last run date for sales
# [watermark.py:21]               No previous runs found for sales
# [files.py:10]                   Getting files to process from ./data/sales/
# [files.py:14]                   Found 7 files to process
# [ingestion.py:19]               Processing sales_20241009.txt
# [files.py:26]                   Reading csv file from ./data/sales/sales_20241009.txt with kwargs {'sep': '~', 'names': ['uuid', 'customer_id', 'product_id', 'quantity', 'price_per_unit', 'total_price', 'sale_date']}
# [dataframes.py:134]             Processing data for sales
# [files.py:55]                   Getting saved file for sales
# [files.py:18]                   Getting save filename for sales
# [files.py:34]                   Reading parquet file from ./final_data/sales.parquet
# [files.py:60]                   File not found at ./final_data/sales.parquet. Creating new file
# [files.py:62]                   sales file has 0 rows
# [dataframes.py:49]              Processing file with 7960 records.
# [dataframes.py:92]              No existing records found. Returning new records.
# [files.py:18]                   Getting save filename for sales
# [files.py:22]                   Saving file with 7960 rows to ./final_data/sales.parquet
# [dataframes.py:165]             Processed 7960 records for sales
# [watermark.py:38]               Updating watermark table with {'source': 'sales', 'processed_rows': 7960, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:02.814533'), 'file_date': Timestamp('2024-10-09 00:00:00'), 'file_id': '87867a87-e0f7-479e-aa39-cf9dcd1f4a8f', 'file_name': 'sales_20241009.txt'}
# [watermark.py:40]               Watermark table now has 8 rows
# [files.py:22]                   Saving file with 8 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed sales_20241009.txt
# [ingestion.py:19]               Processing sales_20241010.txt
# [files.py:26]                   Reading csv file from ./data/sales/sales_20241010.txt with kwargs {'sep': '~', 'names': ['uuid', 'customer_id', 'product_id', 'quantity', 'price_per_unit', 'total_price', 'sale_date']}
# [dataframes.py:134]             Processing data for sales
# [files.py:55]                   Getting saved file for sales
# [files.py:18]                   Getting save filename for sales
# [files.py:34]                   Reading parquet file from ./final_data/sales.parquet
# [files.py:62]                   sales file has 7960 rows
# [dataframes.py:49]              Processing file with 8196 records.
# [dataframes.py:112]             Detected 0 changes and 8196 new records.
# [files.py:18]                   Getting save filename for sales
# [files.py:22]                   Saving file with 16156 rows to ./final_data/sales.parquet
# [dataframes.py:165]             Processed 8196 records for sales
# [watermark.py:38]               Updating watermark table with {'source': 'sales', 'processed_rows': 8196, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:03.013549'), 'file_date': Timestamp('2024-10-10 00:00:00'), 'file_id': 'c5c1189c-17d4-46be-aa0b-2dbfc02d17e3', 'file_name': 'sales_20241010.txt'}
# [watermark.py:40]               Watermark table now has 9 rows
# [files.py:22]                   Saving file with 9 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed sales_20241010.txt
# [ingestion.py:19]               Processing sales_20241011.txt
# [files.py:26]                   Reading csv file from ./data/sales/sales_20241011.txt with kwargs {'sep': '~', 'names': ['uuid', 'customer_id', 'product_id', 'quantity', 'price_per_unit', 'total_price', 'sale_date']}
# [dataframes.py:134]             Processing data for sales
# [files.py:55]                   Getting saved file for sales
# [files.py:18]                   Getting save filename for sales
# [files.py:34]                   Reading parquet file from ./final_data/sales.parquet
# [files.py:62]                   sales file has 16156 rows
# [dataframes.py:49]              Processing file with 8424 records.
# [dataframes.py:112]             Detected 0 changes and 8424 new records.
# [files.py:18]                   Getting save filename for sales
# [files.py:22]                   Saving file with 24580 rows to ./final_data/sales.parquet
# [dataframes.py:165]             Processed 8424 records for sales
# [watermark.py:38]               Updating watermark table with {'source': 'sales', 'processed_rows': 8424, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:03.199566'), 'file_date': Timestamp('2024-10-11 00:00:00'), 'file_id': 'd46a39a0-dc9d-4e79-a025-748921a2c34b', 'file_name': 'sales_20241011.txt'}
# [watermark.py:40]               Watermark table now has 10 rows
# [files.py:22]                   Saving file with 10 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed sales_20241011.txt
# [ingestion.py:19]               Processing sales_20241012.txt
# [files.py:26]                   Reading csv file from ./data/sales/sales_20241012.txt with kwargs {'sep': '~', 'names': ['uuid', 'customer_id', 'product_id', 'quantity', 'price_per_unit', 'total_price', 'sale_date']}
# [dataframes.py:134]             Processing data for sales
# [files.py:55]                   Getting saved file for sales
# [files.py:18]                   Getting save filename for sales
# [files.py:34]                   Reading parquet file from ./final_data/sales.parquet
# [files.py:62]                   sales file has 24580 rows
# [dataframes.py:49]              Processing file with 8983 records.
# [dataframes.py:112]             Detected 0 changes and 8983 new records.
# [files.py:18]                   Getting save filename for sales
# [files.py:22]                   Saving file with 33563 rows to ./final_data/sales.parquet
# [dataframes.py:165]             Processed 8983 records for sales
# [watermark.py:38]               Updating watermark table with {'source': 'sales', 'processed_rows': 8983, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:03.405579'), 'file_date': Timestamp('2024-10-12 00:00:00'), 'file_id': 'e6c276cc-4d9f-4fc2-9f48-1956dcfdc33d', 'file_name': 'sales_20241012.txt'}
# [watermark.py:40]               Watermark table now has 11 rows
# [files.py:22]                   Saving file with 11 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed sales_20241012.txt
# [ingestion.py:19]               Processing sales_20241013.txt
# [files.py:26]                   Reading csv file from ./data/sales/sales_20241013.txt with kwargs {'sep': '~', 'names': ['uuid', 'customer_id', 'product_id', 'quantity', 'price_per_unit', 'total_price', 'sale_date']}
# [dataframes.py:134]             Processing data for sales
# [files.py:55]                   Getting saved file for sales
# [files.py:18]                   Getting save filename for sales
# [files.py:34]                   Reading parquet file from ./final_data/sales.parquet
# [files.py:62]                   sales file has 33563 rows
# [dataframes.py:49]              Processing file with 9573 records.
# [dataframes.py:112]             Detected 0 changes and 9573 new records.
# [files.py:18]                   Getting save filename for sales
# [files.py:22]                   Saving file with 43136 rows to ./final_data/sales.parquet
# [dataframes.py:165]             Processed 9573 records for sales
# [watermark.py:38]               Updating watermark table with {'source': 'sales', 'processed_rows': 9573, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:03.654598'), 'file_date': Timestamp('2024-10-13 00:00:00'), 'file_id': '5a2c404d-e4b8-40ec-8be3-17222ae5d870', 'file_name': 'sales_20241013.txt'}
# [watermark.py:40]               Watermark table now has 12 rows
# [files.py:22]                   Saving file with 12 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed sales_20241013.txt
# [ingestion.py:19]               Processing sales_20241014.txt
# [files.py:26]                   Reading csv file from ./data/sales/sales_20241014.txt with kwargs {'sep': '~', 'names': ['uuid', 'customer_id', 'product_id', 'quantity', 'price_per_unit', 'total_price', 'sale_date']}
# [dataframes.py:134]             Processing data for sales
# [files.py:55]                   Getting saved file for sales
# [files.py:18]                   Getting save filename for sales
# [files.py:34]                   Reading parquet file from ./final_data/sales.parquet
# [files.py:62]                   sales file has 43136 rows
# [dataframes.py:49]              Processing file with 9985 records.
# [dataframes.py:112]             Detected 0 changes and 9985 new records.
# [files.py:18]                   Getting save filename for sales
# [files.py:22]                   Saving file with 53121 rows to ./final_data/sales.parquet
# [dataframes.py:165]             Processed 9985 records for sales
# [watermark.py:38]               Updating watermark table with {'source': 'sales', 'processed_rows': 9985, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:03.894618'), 'file_date': Timestamp('2024-10-14 00:00:00'), 'file_id': '987e52fb-3912-4429-8130-e814521ed0a1', 'file_name': 'sales_20241014.txt'}
# [watermark.py:40]               Watermark table now has 13 rows
# [files.py:22]                   Saving file with 13 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed sales_20241014.txt
# [ingestion.py:19]               Processing sales_20241015.txt
# [files.py:26]                   Reading csv file from ./data/sales/sales_20241015.txt with kwargs {'sep': '~', 'names': ['uuid', 'customer_id', 'product_id', 'quantity', 'price_per_unit', 'total_price', 'sale_date']}
# [dataframes.py:134]             Processing data for sales
# [files.py:55]                   Getting saved file for sales
# [files.py:18]                   Getting save filename for sales
# [files.py:34]                   Reading parquet file from ./final_data/sales.parquet
# [files.py:62]                   sales file has 53121 rows
# [dataframes.py:49]              Processing file with 10652 records.
# [dataframes.py:112]             Detected 0 changes and 10652 new records.
# [files.py:18]                   Getting save filename for sales
# [files.py:22]                   Saving file with 63773 rows to ./final_data/sales.parquet
# [dataframes.py:165]             Processed 10652 records for sales
# [watermark.py:38]               Updating watermark table with {'source': 'sales', 'processed_rows': 10652, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:04.224642'), 'file_date': Timestamp('2024-10-15 00:00:00'), 'file_id': '27622ac6-5bc1-48e4-b89e-377132d408ee', 'file_name': 'sales_20241015.txt'}
# [watermark.py:40]               Watermark table now has 14 rows
# [files.py:22]                   Saving file with 14 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed sales_20241015.txt
# [ingestion.py:12]               Loading product data
# [watermark.py:18]               Getting last run date for product
# [watermark.py:21]               No previous runs found for product
# [files.py:10]                   Getting files to process from ./data/products/
# [files.py:14]                   Found 7 files to process
# [ingestion.py:19]               Processing products_20241009.json
# [files.py:38]                   Reading JSON file from ./data/products/products_20241009.json with kwargs {'orient': 'records', 'dtype': {'name': <class 'str'>, 'product_id': <class 'str'>, 'price': <class 'float'>, 'description': <class 'str'>}, 'parse_dates': ['creation_date']}
# [dataframes.py:134]             Processing data for product
# [files.py:55]                   Getting saved file for product
# [files.py:18]                   Getting save filename for product
# [files.py:34]                   Reading parquet file from ./final_data/product.parquet
# [files.py:60]                   File not found at ./final_data/product.parquet. Creating new file
# [files.py:62]                   product file has 0 rows
# [dataframes.py:49]              Processing file with 5 records.
# [dataframes.py:82]              Detected 0 old records and 5 new records.
# [files.py:18]                   Getting save filename for product
# [files.py:22]                   Saving file with 5 rows to ./final_data/product.parquet
# [dataframes.py:165]             Processed 5 records for product
# [watermark.py:38]               Updating watermark table with {'source': 'product', 'processed_rows': 5, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:04.407658'), 'file_date': Timestamp('2024-10-09 00:00:00'), 'file_id': '34d9105b-ec24-4746-ab50-34ad263f29d8', 'file_name': 'products_20241009.json'}
# [watermark.py:40]               Watermark table now has 15 rows
# [files.py:22]                   Saving file with 15 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed products_20241009.json
# [ingestion.py:19]               Processing products_20241010.json
# [files.py:38]                   Reading JSON file from ./data/products/products_20241010.json with kwargs {'orient': 'records', 'dtype': {'name': <class 'str'>, 'product_id': <class 'str'>, 'price': <class 'float'>, 'description': <class 'str'>}, 'parse_dates': ['creation_date']}
# [dataframes.py:134]             Processing data for product
# [files.py:55]                   Getting saved file for product
# [files.py:18]                   Getting save filename for product
# [files.py:34]                   Reading parquet file from ./final_data/product.parquet
# [files.py:62]                   product file has 5 rows
# [dataframes.py:49]              Processing file with 6 records.
# [dataframes.py:82]              Detected 5 old records and 6 new records.
# [files.py:18]                   Getting save filename for product
# [files.py:22]                   Saving file with 11 rows to ./final_data/product.parquet
# [dataframes.py:165]             Processed 6 records for product
# [watermark.py:38]               Updating watermark table with {'source': 'product', 'processed_rows': 6, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:04.504666'), 'file_date': Timestamp('2024-10-10 00:00:00'), 'file_id': 'd94cefc1-6b70-4b96-a367-e545992293f1', 'file_name': 'products_20241010.json'}
# [watermark.py:40]               Watermark table now has 16 rows
# [files.py:22]                   Saving file with 16 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed products_20241010.json
# [ingestion.py:19]               Processing products_20241011.json
# [files.py:38]                   Reading JSON file from ./data/products/products_20241011.json with kwargs {'orient': 'records', 'dtype': {'name': <class 'str'>, 'product_id': <class 'str'>, 'price': <class 'float'>, 'description': <class 'str'>}, 'parse_dates': ['creation_date']}
# [dataframes.py:134]             Processing data for product
# [files.py:55]                   Getting saved file for product
# [files.py:18]                   Getting save filename for product
# [files.py:34]                   Reading parquet file from ./final_data/product.parquet
# [files.py:62]                   product file has 11 rows
# [dataframes.py:49]              Processing file with 7 records.
# [dataframes.py:82]              Detected 6 old records and 7 new records.
# [files.py:18]                   Getting save filename for product
# [files.py:22]                   Saving file with 18 rows to ./final_data/product.parquet
# [dataframes.py:165]             Processed 7 records for product
# [watermark.py:38]               Updating watermark table with {'source': 'product', 'processed_rows': 7, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:04.601670'), 'file_date': Timestamp('2024-10-11 00:00:00'), 'file_id': 'e1f47a64-2416-4e1b-a3f8-1d4e91f6fb99', 'file_name': 'products_20241011.json'}
# [watermark.py:40]               Watermark table now has 17 rows
# [files.py:22]                   Saving file with 17 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed products_20241011.json
# [ingestion.py:19]               Processing products_20241012.json
# [files.py:38]                   Reading JSON file from ./data/products/products_20241012.json with kwargs {'orient': 'records', 'dtype': {'name': <class 'str'>, 'product_id': <class 'str'>, 'price': <class 'float'>, 'description': <class 'str'>}, 'parse_dates': ['creation_date']}
# [dataframes.py:134]             Processing data for product
# [files.py:55]                   Getting saved file for product
# [files.py:18]                   Getting save filename for product
# [files.py:34]                   Reading parquet file from ./final_data/product.parquet
# [files.py:62]                   product file has 18 rows
# [dataframes.py:49]              Processing file with 8 records.
# [dataframes.py:82]              Detected 7 old records and 8 new records.
# [files.py:18]                   Getting save filename for product
# [files.py:22]                   Saving file with 26 rows to ./final_data/product.parquet
# [dataframes.py:165]             Processed 8 records for product
# [watermark.py:38]               Updating watermark table with {'source': 'product', 'processed_rows': 8, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:04.691676'), 'file_date': Timestamp('2024-10-12 00:00:00'), 'file_id': 'fd94c838-6b19-4903-a308-13fd79d191f3', 'file_name': 'products_20241012.json'}
# [watermark.py:40]               Watermark table now has 18 rows
# [files.py:22]                   Saving file with 18 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed products_20241012.json
# [ingestion.py:19]               Processing products_20241013.json
# [files.py:38]                   Reading JSON file from ./data/products/products_20241013.json with kwargs {'orient': 'records', 'dtype': {'name': <class 'str'>, 'product_id': <class 'str'>, 'price': <class 'float'>, 'description': <class 'str'>}, 'parse_dates': ['creation_date']}
# [dataframes.py:134]             Processing data for product
# [files.py:55]                   Getting saved file for product
# [files.py:18]                   Getting save filename for product
# [files.py:34]                   Reading parquet file from ./final_data/product.parquet
# [files.py:62]                   product file has 26 rows
# [dataframes.py:49]              Processing file with 9 records.
# [dataframes.py:82]              Detected 8 old records and 9 new records.
# [files.py:18]                   Getting save filename for product
# [files.py:22]                   Saving file with 35 rows to ./final_data/product.parquet
# [dataframes.py:165]             Processed 9 records for product
# [watermark.py:38]               Updating watermark table with {'source': 'product', 'processed_rows': 9, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:04.780684'), 'file_date': Timestamp('2024-10-13 00:00:00'), 'file_id': '51b1dbe3-c3dc-4a36-b341-c2a3f0307c24', 'file_name': 'products_20241013.json'}
# [watermark.py:40]               Watermark table now has 19 rows
# [files.py:22]                   Saving file with 19 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed products_20241013.json
# [ingestion.py:19]               Processing products_20241014.json
# [files.py:38]                   Reading JSON file from ./data/products/products_20241014.json with kwargs {'orient': 'records', 'dtype': {'name': <class 'str'>, 'product_id': <class 'str'>, 'price': <class 'float'>, 'description': <class 'str'>}, 'parse_dates': ['creation_date']}
# [dataframes.py:134]             Processing data for product
# [files.py:55]                   Getting saved file for product
# [files.py:18]                   Getting save filename for product
# [files.py:34]                   Reading parquet file from ./final_data/product.parquet
# [files.py:62]                   product file has 35 rows
# [dataframes.py:49]              Processing file with 10 records.
# [dataframes.py:82]              Detected 9 old records and 10 new records.
# [files.py:18]                   Getting save filename for product
# [files.py:22]                   Saving file with 45 rows to ./final_data/product.parquet
# [dataframes.py:165]             Processed 10 records for product
# [watermark.py:38]               Updating watermark table with {'source': 'product', 'processed_rows': 10, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:04.869692'), 'file_date': Timestamp('2024-10-14 00:00:00'), 'file_id': '3d5ba66c-f9c8-4f7f-9211-158da0a0d014', 'file_name': 'products_20241014.json'}
# [watermark.py:40]               Watermark table now has 20 rows
# [files.py:22]                   Saving file with 20 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed products_20241014.json
# [ingestion.py:19]               Processing products_20241015.json
# [files.py:38]                   Reading JSON file from ./data/products/products_20241015.json with kwargs {'orient': 'records', 'dtype': {'name': <class 'str'>, 'product_id': <class 'str'>, 'price': <class 'float'>, 'description': <class 'str'>}, 'parse_dates': ['creation_date']}
# [dataframes.py:134]             Processing data for product
# [files.py:55]                   Getting saved file for product
# [files.py:18]                   Getting save filename for product
# [files.py:34]                   Reading parquet file from ./final_data/product.parquet
# [files.py:62]                   product file has 45 rows
# [dataframes.py:49]              Processing file with 11 records.
# [dataframes.py:82]              Detected 10 old records and 11 new records.
# [files.py:18]                   Getting save filename for product
# [files.py:22]                   Saving file with 56 rows to ./final_data/product.parquet
# [dataframes.py:165]             Processed 11 records for product
# [watermark.py:38]               Updating watermark table with {'source': 'product', 'processed_rows': 11, 'error_rows': 0, 'process_time': Timestamp('2024-11-22 16:24:04.975700'), 'file_date': Timestamp('2024-10-15 00:00:00'), 'file_id': '00f5c4a0-0ad7-43b0-a21e-0eeda1853775', 'file_name': 'products_20241015.json'}
# [watermark.py:40]               Watermark table now has 21 rows
# [files.py:22]                   Saving file with 21 rows to ./watermark.parquet
# [watermark.py:42]               Watermark table saved to ./watermark.parquet
# [ingestion.py:25]               Processed products_20241015.json

# %% [markdown]
# ## Report Generation

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# ### Customer Growth

# %%
customers = pd.read_parquet('./final_data/customer.parquet')

dates = customers['effective_from'].unique()

data = []
for date in sorted(dates):
    snapshot = customers[(customers['effective_from'] <= date) & (customers['expiry_date'] > date)]
    data.append({'date': date, 'count': len(snapshot)})

df = pd.DataFrame(data)
df.plot(x='date', y='count')
plt.title('Customer Growth')
plt.xlabel('Date')
plt.ylabel('Number of Customers')
plt.show()

# %% [markdown]
# ### Sales By Membership

# %%
# Sales By Members
customers = pd.read_parquet('./final_data/customer.parquet')

dates = customers['effective_from'].unique()
sales = pd.read_parquet('./final_data/sales.parquet')
merged = sales.merge(customers, on='customer_id', how='outer')
merged = merged[(merged['effective_from_y'] <= merged['sale_date']) & (merged['expiry_date_y'] > merged['sale_date'])]
data = merged.groupby(['sale_date', 'membership_status'])['total_price'].sum().unstack().fillna(0)

data.plot()
plt.title('Sales by Membership Status')
plt.xlabel('Date')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# ### Product Sale Breakdown

# %%
# pivot of most popular products over time from members vs non-members

products = pd.read_parquet('./final_data/product.parquet')
customers = pd.read_parquet('./final_data/customer.parquet')
sales = pd.read_parquet('./final_data/sales.parquet')

merged = sales.merge(customers, on='customer_id', how='outer')
merged = merged[(merged['effective_from_y'] <= merged['sale_date']) & (merged['expiry_date_y'] > merged['sale_date'])]
merged_with_products = merged.merge(products, on='product_id', how='left')
data = merged_with_products.groupby(['sale_date', 'membership_status', 'name'])['total_price'].sum().unstack().fillna(0)

data
# Out:
# name                              Camera  External Hard Drive  Headphones  \
# sale_date  membership_status
# 2024-10-09 active                   0.00                 0.00        0.00
#            inactive                 0.00                 0.00        0.00
# 2024-10-10 active                   0.00                 0.00        0.00
#            inactive                 0.00                 0.00        0.00
# 2024-10-11 active                   0.00                 0.00        0.00
#            inactive                 0.00                 0.00        0.00
# 2024-10-12 active                   0.00                 0.00   542564.00
#            inactive                 0.00                 0.00  1028280.00
# 2024-10-13 active             1912712.40                 0.00   546459.20
#            inactive           3572453.16                 0.00  1053483.20
# 2024-10-14 active             2191213.92            143835.64   590544.04
#            inactive           3262410.24            237151.36  1028406.56
# 2024-10-15 active             1905392.70            144721.08   557222.40
#            inactive           3307258.20            229886.16   890265.60
#
# name                               Laptop     Monitor      Mouse     Printer  \
# sale_date  membership_status
# 2024-10-09 active              7714256.20  1425283.65  205094.40  1388914.80
#            inactive           16059291.36  3232253.43  481219.20  2960967.10
# 2024-10-10 active              6033176.45  1316356.72  180747.63  1140371.26
#            inactive           13102433.40  2879737.56  332764.32  2472595.02
# 2024-10-11 active              5935608.00  1181432.00  173135.76  1155834.75
#            inactive           10684094.40  2231773.60  315731.36  2439908.10
# 2024-10-12 active              5280251.34  1255896.88  167447.28  1133237.07
#            inactive            9652723.08  2266911.36  302211.00  2124191.79
# 2024-10-13 active              4290997.62  1222725.00  151603.20  1278061.40
#            inactive            8423324.91  2163420.00  250145.28  2018991.59
# 2024-10-14 active              4090971.50  1045593.36  127227.66  1179916.22
#            inactive            6839297.50  1805872.32  228927.44  1955488.92
# 2024-10-15 active              3683285.62  1110422.04  156149.07  1074436.44
#            inactive            6248117.26  1670183.97  231034.79  1704604.44
#
# name                              Router  Smartphone  Smartwatch     Tablet
# sale_date  membership_status
# 2024-10-09 active             1356263.16        0.00        0.00       0.00
#            inactive           2758824.46        0.00        0.00       0.00
# 2024-10-10 active             1218046.83        0.00   533694.66       0.00
#            inactive           2198976.78        0.00  1072222.26       0.00
# 2024-10-11 active             1110109.28  2913344.85   488637.60       0.00
#            inactive           1983107.84  4937994.10  1000088.10       0.00
# 2024-10-12 active              922285.98  2713591.55   531843.30       0.00
#            inactive           1627122.42  5344715.05   885710.28       0.00
# 2024-10-13 active              833729.96  2549503.60   448796.70       0.00
#            inactive           1531708.50  4846424.80   960468.30       0.00
# 2024-10-14 active              850611.58  2531520.25   425252.52       0.00
#            inactive           1298721.97  4124345.40   791182.98       0.00
# 2024-10-15 active              711252.92  2425675.30   386894.04  277844.45
#            inactive           1223078.36  4177334.20   695503.50  490363.64
